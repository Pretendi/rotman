# %%
# %matplotlib inline

import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter

# %%
# CWD (Current Working Directory) is the directory this notebook is located
CWD = os.getcwd()
# Within CWD, create a sub-directory called data, to put your data in obviously.
DATA_DIR = os.path.join(os.getcwd(), 'data')
# Create another sub-directory called out, to put any plots or saved models
OUT_DIR = os.path.join(os.getcwd(), 'out')

# %%
dataset = pd.read_csv('credit_data.csv')

# %%
dataset.head()
# Out:
#    Credit_Limit  Sex  Education  Marital_Status   Age  Jan_Repay_Status  \
# 0        9600.0  1.0        3.0             3.0  32.0               6.0
# 1       14400.0  2.0        3.0             2.0  30.0              -2.0
# 2        8100.0  1.0        1.0             2.0  29.0              -1.0
# 3        2700.0  2.0        2.0             1.0  31.0               0.0
# 4       14500.0  2.0        2.0             1.0  37.0              -2.0
#
#    Previous_Payment_Prior_Jan  Jan_Statement  Feb_Repay_Status  \
# 0                       110.0          138.0               5.0
# 1                         0.0          132.0              -2.0
# 2                       133.0            7.0              -1.0
# 3                       104.0         2891.0               0.0
# 4                       309.0          403.0              -2.0
#
#    Previous_Payment_Prior_Feb         ...           Apr_Repay_Status  \
# 0                      2847.0         ...                        7.0
# 1                         0.0         ...                       -2.0
# 2                      1700.0         ...                       -1.0
# 3                       140.0         ...                        0.0
# 4                        94.0         ...                       -2.0
#
#    Previous_Payment_Prior_Apr  Apr_Statement  May_Repay_Status  \
# 0                       331.0         1080.0              12.0
# 1                         0.0            0.0              -2.0
# 2                       751.0           -4.0              -1.0
# 3                        40.0         2842.0               0.0
# 4                       362.0          381.0              -2.0
#
#    Previous_Payment_Prior_May  May_Statement  Jun_Repay_Status  \
# 0                       535.0         1671.0               3.0
# 1                        45.0            0.0              -2.0
# 2                       498.0          747.0              -1.0
# 3                        60.0         1187.0               0.0
# 4                         0.0          362.0              -2.0
#
#    Previous_Payment_Prior_Jun  Jun_Statement  July_Payment_Status
# 0                      4800.0         6799.0                  1.0
# 1                       136.0           45.0                  0.0
# 2                       381.0          496.0                  0.0
# 3                        19.0         1153.0                  0.0
# 4                       116.0            0.0                  0.0
#
# [5 rows x 24 columns]

# %%
plotter1 = dataset[['Sex', 'Education', 'Marital_Status', 'Age', 'July_Payment_Status']]

# %%
sns_plot = sns.pairplot(plotter1, hue="July_Payment_Status", size=10)

# %%
sns_plot = sns.pairplot(dataset, hue="July_Payment_Status", size=3)
